# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# C:\Users\HP\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
df = pd.read_csv('creditcard.csv')
df.shape
# Out:
# (284807, 31)

# %%
df.head(5)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552563e-15  2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15
# ...

# %% [markdown]
# Since the data size is very large(nearly 300k) we will use only a fraction of data which can still give us very high accuracy because we just need to make binary classification

# %%
df = df.sample(frac=0.25,random_state=27)
df.shape
# Out:
# (71202, 31)

# %%
df.hist(figsize=(20,20))
plt.show()

# %%
(df['Class'].value_counts()/len(df)).plot.bar()
print(df['Class'].value_counts()/len(df))
# Out:
# 0    0.998146
# 1    0.001854
# Name: Class, dtype: float64

# %% [markdown]
# Only 0.18% of all transactions result in a fraud

# %%
# making co-relation matrix for better understanding of relations b/w the data
CoMatrix = df.corr()
import seaborn
plt.figure(figsize=(7,5),dpi=120)
seaborn.heatmap(CoMatrix)

# %% [markdown]
# Since columns like V14,V12,V16,V15,V17,V18,V7,V5 have negative co-relation with target variable we need to consider them in our prediction model

# %%
df.drop(['V14','V12','V16','V15','V17','V18','V7','V5'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-be4b918d8688> in <module>
# ----> 1 df.drop(['V14','V12','V16','V15','V17','V18','V7','V5'],axis=1,inplace=True)
#       2 print(df.shape)
#       3 print(df.columns)
#       4 df.head(5)
#       5 df['V14']
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
# ...

# %%
print(df.shape)
print(df.columns)
df.head(5)
# Out:
# (71202, 23)
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V6', 'V8', 'V9', 'V10', 'V11', 'V13',
#        'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28',
#        'Amount', 'Class'],
#       dtype='object')
#             Time        V1        V2        V3        V4        V6        V8  \
# 47747    43343.0  1.209971 -0.158081  0.685984 -0.019681 -0.775662  0.015835
# 225706  144357.0  0.107350  0.718755 -0.059117 -0.821294 -1.189281 -0.395374
# 255432  157223.0 -0.992778  1.374399 -1.681843 -0.123910 -1.394937 -0.066849
# 202435  134327.0  2.084975 -1.678690 -0.492561 -1.592379 -0.284969 -0.051357
# 119363   75422.0  1.176209  0.183813  0.514542  0.450080 -0.187294  0.056852
#
#               V9       V10       V11  ...       V21       V22       V23  \
# 47747   0.545579 -0.224426  0.088800  ... -0.096262 -0.294659  0.177728
# 225706 -0.185327 -0.841789 -0.908705  ... -0.043964 -0.030030 -0.042275
# ...

# %%
x = df.drop(['Class'],axis=1)
y = df['Class']
x.shape, y.shape
# Out:
# ((71202, 22), (71202,))
